# %% [markdown]
# # LDA - Latent Dirichlet Allocation

# %% [markdown]
# Latent Dirichlet Allocation (LDA) is a generative probabilistic model for collections of discrete data (e.g., documents). It assumes each document is a mixture of a small number of topics, and each topic is a probability distribution over words. Using Dirichlet priors, LDA infers the document–topic and topic–word distributions (typically via variational inference or Gibbs sampling), enabling unsupervised topic discovery and document representation for tasks like exploration, clustering, or feature extraction.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np

# %%
url = "https://www.gutenberg.org/files/55/55-h/55-h.htm"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

for script in soup(["script", "style"]):
    script.extract()

text = soup.get_text()
documents = []
documents.append(text)

# %%
url = "https://www.gutenberg.org/files/54/54-h/54-h.htm"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

url = "https://www.gutenberg.org/files/33361/33361-h/33361-h.htm"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

url = "https://www.gutenberg.org/files/22566/22566-h/22566-h.htm"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

url = "https://www.gutenberg.org/files/26624/26624-h/26624-h.htm"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

# %%
cv = CountVectorizer()
df = cv.fit_transform(documents)
vocab = cv.get_feature_names_out()
print(vocab)
print(df)
# Out:
# ['00' '000' '10' ... 'zoroaster' 'zuz' 'zy']
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 21180 stored elements and shape (5, 9138)>
#   Coords	Values
#   (0, 8064)	3007
#   (0, 8997)	24
#   (0, 8978)	40
#   (0, 5455)	850
#   (0, 5590)	165
#   (0, 6149)	3
#   (0, 3797)	3
#   (0, 7617)	7
#   (0, 2712)	2
#   (0, 252)	2
#   (0, 1342)	92
#   (0, 3398)	2
#   (0, 891)	2
#   (0, 8097)	149
#   (0, 1113)	1
#   (0, 4374)	261
#   (0, 2266)	1
#   (0, 8199)	1118
#   (0, 5236)	191
#   (0, 3635)	102
#   (0, 3420)	14
#   (0, 1804)	5
#   (0, 8913)	7
#   (0, 1896)	2
#   (0, 4349)	2
#   :	:
#   (4, 4220)	2
#   (4, 4866)	2
#   (4, 9056)	2
#   (4, 2840)	2
#   (4, 1402)	1
#   (4, 9006)	2
#   (4, 2462)	1
#   (4, 8290)	1
#   (4, 846)	1
#   (4, 6723)	1
#   (4, 4769)	1
#   (4, 1594)	3
#   (4, 4971)	1
#   (4, 2349)	1
#   (4, 5960)	1
#   (4, 1077)	1
#   (4, 1746)	1
#   (4, 3908)	2
#   (4, 6094)	1
#   (4, 0)	1
#   (4, 6000)	1
#   (4, 6740)	1
#   (4, 5053)	1
#   (4, 3983)	1
#   (4, 4833)	1

# %%
print(vocab[8064])
# Out:
# the

# %%
lda = LatentDirichletAllocation(n_components=5, doc_topic_prior=1)
lda.fit(df)
# Out:
# LatentDirichletAllocation(doc_topic_prior=1, n_components=5)

# %%
topic_words = {}
n_top_words = 10
for topic_idx, topic in enumerate(lda.components_):

    word_idx = np.argsort(topic)[::-1][:n_top_words]

    topic_words[topic_idx] = [vocab[i] for i in word_idx]

for topic, words in topic_words.items():
    print(f"Topic {topic}: {', '.join(words)}")
    print(' %s' % ', '.join(words))
# Out:
# Topic 0: the, and, to, of, in, you, it, was, that, he
#  the, and, to, of, in, you, it, was, that, he
# Topic 1: steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore
#  steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore
# Topic 2: steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore
#  steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore
# Topic 3: steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore
#  steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore
# Topic 4: steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore
#  steady, loudest, longing, lonesome, lodged, youngster, starts, stereotyped, soul, sore

# %%
cv = CountVectorizer(stop_words="english")
df = cv.fit_transform(documents)
vocab = cv.get_feature_names_out()
print(vocab)
print(df)
# Out:
# ['00' '000' '10' ... 'zoroaster' 'zuz' 'zy']
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 19881 stored elements and shape (5, 8846)>
#   Coords	Values
#   (0, 8712)	24
#   (0, 8693)	40
#   (0, 5407)	165
#   (0, 5962)	3
#   (0, 3693)	3
#   (0, 7403)	7
#   (0, 2643)	2
#   (0, 252)	2
#   (0, 3301)	2
#   (0, 858)	2
#   (0, 1064)	1
#   (0, 2205)	1
#   (0, 3531)	102
#   (0, 3323)	14
#   (0, 1747)	5
#   (0, 8632)	7
#   (0, 1838)	2
#   (0, 4224)	2
#   (0, 1450)	48
#   (0, 2101)	16
#   (0, 4035)	2
#   (0, 1928)	2
#   (0, 5060)	21
#   (0, 4036)	2
#   (0, 2496)	369
#   :	:
#   (4, 4098)	2
#   (4, 4731)	2
#   (4, 8770)	2
#   (4, 2765)	2
#   (4, 1346)	1
#   (4, 8721)	2
#   (4, 2399)	1
#   (4, 8042)	1
#   (4, 813)	1
#   (4, 6533)	1
#   (4, 4635)	1
#   (4, 1538)	3
#   (4, 4834)	1
#   (4, 2287)	1
#   (4, 5773)	1
#   (4, 1028)	1
#   (4, 1689)	1
#   (4, 3800)	2
#   (4, 5907)	1
#   (4, 0)	1
#   (4, 5813)	1
#   (4, 6550)	1
#   (4, 4914)	1
#   (4, 3870)	1
#   (4, 4699)	1

# %%
lda = LatentDirichletAllocation(n_components=5, doc_topic_prior=1)
lda.fit(df)
# Out:
# LatentDirichletAllocation(doc_topic_prior=1, n_components=5)

# %%
topic_words = {}
n_top_words = 10

for topic_idx, topic in enumerate(lda.components_):
    word_idx = np.argsort(topic)[::-1][:n_top_words]
    topic_words[topic_idx] = [vocab[i] for i in word_idx]

for topic_idx, words in topic_words.items():
    print(f"Topic {topic_idx}: {', '.join(words)}")
# Out:
# Topic 0: dorothy, said, pg, little, scarecrow, oz, wizard, asked, girl, woodman
# Topic 1: scramble, bewilderment, leaps, april, suffered, legged, nearing, basin, alas, politeness
# Topic 2: scramble, bewilderment, leaps, april, suffered, legged, nearing, basin, alas, politeness
# Topic 3: said, tip, scarecrow, horse, jack, saw, woodman, tin, pumpkinhead, mombi
# Topic 4: dorothy, man, shaggy, said, bright, button, little, asked, ozma, don
