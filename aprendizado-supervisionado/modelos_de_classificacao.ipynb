# %% [markdown]
# # Modelos de Classificação

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["target"] = iris.target
df["target_name"] = iris.target_names[df["target"]]
df.drop(columns=["target"], inplace=True)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target_name
# 0                5.1               3.5  ...               0.2       setosa
# 1                4.9               3.0  ...               0.2       setosa
# 2                4.7               3.2  ...               0.2       setosa
# 3                4.6               3.1  ...               0.2       setosa
# 4                5.0               3.6  ...               0.2       setosa
#
# [5 rows x 5 columns]

# %%
x = df[["sepal length (cm)", "sepal width (cm)", "petal length (cm)", "petal width (cm)"]]

y = df["target_name"]

# %% [markdown]
# ## Divindo o conjunto de dados 70% para treino 30% para teste

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=23)

# %% [markdown]
# ## Regressão Logística

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr_model.predict(x_test)
y_pred[:5]
# Out:
# array(['virginica', 'virginica', 'versicolor', 'setosa', 'virginica'],
#       dtype=object)

# %%
y_test.head()
# Out:
# 139     virginica
# 125     virginica
# 67     versicolor
# 3          setosa
# 113     virginica
# Name: target_name, dtype: str

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, average="micro")
rec = recall_score(y_test, y_pred, average="micro")
f1 = f1_score(y_test, y_pred, average="micro")
print(f"Acurácia: {acc:.2f}")
print(f"Precisão: {prec:.2f}")
print(f"Recall: {rec:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Acurácia: 1.00
# Precisão: 1.00
# Recall: 1.00
# F1-Score: 1.00

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_model.predict(x_test)

# %%
y_pred[:5]
# Out:
# array(['virginica', 'virginica', 'versicolor', 'setosa', 'virginica'],
#       dtype=object)

# %%
y_test[:5]
# Out:
# 139     virginica
# 125     virginica
# 67     versicolor
# 3          setosa
# 113     virginica
# Name: target_name, dtype: str

# %%
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, average="micro")
rec = recall_score(y_test, y_pred, average="micro")
f1 = f1_score(y_test, y_pred, average="micro")
print(f"Acurácia: {acc:.2f}")
print(f"Precisão: {prec:.2f}")
print(f"Recall: {rec:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Acurácia: 0.98
# Precisão: 0.98
# Recall: 0.98
# F1-Score: 0.98

# %%
number_neighbors = range(1,105)
accuracy_dict = {}

for i in number_neighbors:
    knn_model = KNeighborsClassifier(n_neighbors=i)
    knn_model.fit(x_train, y_train)
    y_pred = knn_model.predict(x_test)
    accuracy_dict[i] = accuracy_score(y_test, y_pred)

# %%
accuracy_dict
# Out:
# {1: 0.9777777777777777,
#  2: 0.9777777777777777,
#  3: 0.9777777777777777,
#  4: 0.9777777777777777,
#  5: 1.0,
#  6: 0.9777777777777777,
#  7: 1.0,
#  8: 1.0,
#  9: 1.0,
#  10: 0.9777777777777777,
#  11: 1.0,
#  12: 1.0,
#  13: 1.0,
#  14: 1.0,
#  15: 1.0,
#  16: 1.0,
#  17: 1.0,
#  18: 1.0,
#  19: 1.0,
#  20: 1.0,
#  21: 0.9777777777777777,
#  22: 0.9555555555555556,
#  23: 0.9777777777777777,
#  24: 0.9555555555555556,
#  25: 0.9555555555555556,
#  26: 0.9777777777777777,
#  27: 0.9777777777777777,
#  28: 0.9777777777777777,
#  29: 0.9777777777777777,
#  30: 0.9777777777777777,
#  31: 0.9555555555555556,
#  32: 0.9555555555555556,
#  33: 0.9555555555555556,
#  34: 0.9555555555555556,
#  35: 0.9555555555555556,
#  36: 0.9555555555555556,
#  37: 0.9777777777777777,
#  38: 0.9555555555555556,
#  39: 0.9555555555555556,
#  40: 0.9555555555555556,
#  41: 0.9555555555555556,
#  42: 0.9555555555555556,
#  43: 0.9555555555555556,
#  44: 0.9333333333333333,
#  45: 0.9333333333333333,
#  46: 0.9333333333333333,
#  47: 0.9333333333333333,
#  48: 0.9333333333333333,
#  49: 0.9333333333333333,
#  50: 0.9333333333333333,
#  51: 0.9333333333333333,
#  52: 0.9333333333333333,
#  53: 0.9333333333333333,
#  54: 0.9111111111111111,
#  55: 0.9333333333333333,
#  56: 0.9333333333333333,
#  57: 0.9333333333333333,
#  58: 0.9111111111111111,
#  59: 0.9111111111111111,
#  60: 0.9111111111111111,
#  61: 0.9111111111111111,
#  62: 0.9111111111111111,
#  63: 0.9333333333333333,
#  64: 0.9111111111111111,
#  65: 0.9111111111111111,
#  66: 0.9333333333333333,
#  67: 0.8666666666666667,
#  68: 0.7777777777777778,
#  69: 0.6666666666666666,
#  70: 0.5111111111111111,
#  71: 0.5333333333333333,
#  72: 0.5333333333333333,
#  73: 0.4444444444444444,
#  74: 0.4444444444444444,
#  75: 0.4444444444444444,
#  76: 0.4444444444444444,
#  77: 0.4444444444444444,
#  78: 0.4444444444444444,
#  79: 0.4444444444444444,
#  80: 0.4444444444444444,
#  81: 0.4444444444444444,
#  82: 0.4444444444444444,
#  83: 0.4444444444444444,
#  84: 0.4444444444444444,
#  85: 0.4444444444444444,
#  86: 0.4444444444444444,
#  87: 0.4444444444444444,
#  88: 0.4444444444444444,
#  89: 0.4444444444444444,
#  90: 0.4444444444444444,
#  91: 0.4444444444444444,
#  92: 0.4444444444444444,
#  93: 0.4444444444444444,
#  94: 0.4444444444444444,
#  95: 0.4444444444444444,
#  96: 0.4444444444444444,
#  97: 0.4444444444444444,
#  98: 0.4444444444444444,
#  99: 0.4444444444444444,
#  100: 0.4444444444444444,
#  101: 0.4444444444444444,
#  102: 0.4444444444444444,
#  103: 0.4222222222222222,
#  104: 0.4222222222222222}

# %%
plt.plot(number_neighbors, accuracy_dict.values())
plt.xlabel("Número de Vizinhos")
plt.ylabel("Acurácia")
plt.title("Acurácia do KNN para Diferentes Valores de K")
plt.show()

# %% [markdown]
# ## Árvore de Decisão

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt_model.predict(x_test)

# %%
y_pred[:5]
# Out:
# array(['virginica', 'virginica', 'versicolor', 'setosa', 'virginica'],
#       dtype=object)

# %%
y_test[:5]
# Out:
# 139     virginica
# 125     virginica
# 67     versicolor
# 3          setosa
# 113     virginica
# Name: target_name, dtype: str

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.9777777777777777

# %%
from sklearn import tree

tree.plot_tree(dt_model, feature_names=x.columns, class_names=y.unique(), impurity=False, filled=True)
# Out:
# [Text(0.5416666666666666, 0.9285714285714286, 'petal length (cm) <= 2.35\nsamples = 105\nvalue = [32, 36, 37]\nclass = virginica'),
#  Text(0.4583333333333333, 0.7857142857142857, 'samples = 32\nvalue = [32, 0, 0]\nclass = setosa'),
#  Text(0.5, 0.8571428571428572, 'True  '),
#  Text(0.625, 0.7857142857142857, 'petal width (cm) <= 1.75\nsamples = 73\nvalue = [0, 36, 37]\nclass = virginica'),
#  Text(0.5833333333333333, 0.8571428571428572, '  False'),
#  Text(0.4166666666666667, 0.6428571428571429, 'petal length (cm) <= 5.35\nsamples = 39\nvalue = [0, 35, 4]\nclass = versicolor'),
#  Text(0.3333333333333333, 0.5, 'petal width (cm) <= 1.65\nsamples = 37\nvalue = [0, 35, 2]\nclass = versicolor'),
#  Text(0.16666666666666666, 0.35714285714285715, 'petal length (cm) <= 4.95\nsamples = 35\nvalue = [0, 34, 1]\nclass = versicolor'),
#  Text(0.08333333333333333, 0.21428571428571427, 'samples = 33\nvalue = [0, 33, 0]\nclass = versicolor'),
#  Text(0.25, 0.21428571428571427, 'petal length (cm) <= 5.05\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.16666666666666666, 0.07142857142857142, 'samples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.3333333333333333, 0.07142857142857142, 'samples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.5, 0.35714285714285715, 'sepal length (cm) <= 5.8\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.4166666666666667, 0.21428571428571427, 'samples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.5833333333333334, 0.21428571428571427, 'samples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.5, 0.5, 'samples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.8333333333333334, 0.6428571428571429, 'petal length (cm) <= 4.85\nsamples = 34\nvalue = [0, 1, 33]\nclass = virginica'),
#  Text(0.75, 0.5, 'sepal length (cm) <= 5.95\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.6666666666666666, 0.35714285714285715, 'samples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.8333333333333334, 0.35714285714285715, 'samples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.9166666666666666, 0.5, 'samples = 32\nvalue = [0, 0, 32]\nclass = virginica')]

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()
svc_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = svc_model.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.8

# %% [markdown]
# ## Redes Neurais Artificiais (RNA)

# %% [markdown]
# ### Perceptron

# %%
from sklearn.linear_model import Perceptron

# %%
x = df[["sepal length (cm)", "sepal width (cm)"]]
y = df["target_name"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
per_model = Perceptron()
per_model.fit(x_train, y_train)
# Out:
# Perceptron()

# %%
y_pred = per_model.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.7111111111111111

# %% [markdown]
# ### Multilayer Perceptron (MLP)

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_model = MLPClassifier()
mlp_model.fit(x_train, y_train)
# Out:
# /workspaces/FIAP_POS_ML_MOD3/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
y_pred = mlp_model.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.7333333333333333
