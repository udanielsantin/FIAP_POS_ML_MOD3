# %% [markdown]
# # Técnicas de Otimização e Ajuste Fino

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,KFold,GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.svm import SVR

# %% [markdown]
# ## Validação Cruzada
# **Overfitting, Underfitting and Good Fit/Robust (Generalização)**

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df = df[['price','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront']]
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0

# %%
x = df.drop('price',axis=1)
y = df['price']

# %%
min_max_scaler = StandardScaler()
x = min_max_scaler.fit_transform(x)

# %%
lr_model = LinearRegression()

# %%
k = 5
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
mape_scores = []

# %%
for train_index, test_index in kfold.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    lr_model.fit(x_train, y_train)

    y_pred = lr_model.predict(x_test)

    mape = mean_absolute_percentage_error(y_test, y_pred)
    mape_scores.append(mape)

# %%
mape_scores
# Out:
# [0.3439581880058968,
#  0.34797610372682075,
#  0.34657027263314844,
#  0.34294743291873186,
#  0.34968140400493636]

# %%
mape_mean = np.mean(mape_scores)

mape_mean
# Out:
# np.float64(0.34622668025790687)

# %% [markdown]
# ## Separando 10% dos dados para o teste final

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=42)

# %%
lr_model = LinearRegression()

k = 5

kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
mape_scores = []

# %%
for train_index, test_index in kfold.split(x_train,y_train):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    lr_model.fit(x_train, y_train)

    y_pred = lr_model.predict(x_test)

    mape = mean_absolute_percentage_error(y_test, y_pred)
    mape_scores.append(mape)

# %%
mape_scores
# Out:
# [0.35635601604996126,
#  0.3494394239157484,
#  0.3460291349615621,
#  0.34982346859002256,
#  0.35387585239442787]

# %%
mape_mean = np.mean(mape_scores)

mape_mean
# Out:
# np.float64(0.3511047791823444)

# %%
y_pred_2 = lr_model.predict(x_test)

# %%
mape_score_2 = mean_absolute_percentage_error(y_test, y_pred_2)
mape_score_2
# Out:
# 0.35387585239442787

# %% [markdown]
# ## Ajuste de Hiperparãmetros

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=42)

# %%
parameters = { 
    'kernel' : ['linear', 'rbf'],
    'C' : [1, 10]
}

# %%
svr = SVR()

# %%
clf = GridSearchCV(svr, parameters)

# %%
clf.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [1, 10], 'kernel': ['linear', 'rbf']})

# %%
df_results = pd.DataFrame(clf.cv_results_)
df_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       6.288333      0.365461         0.840467        0.124909        1
# 1       9.269238      2.429469         1.983383        0.135757        1
# 2       5.835795      0.028263         0.761009        0.041297       10
# 3       9.922866      1.958938         2.287281        0.310816       10
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.000528
# 1          rbf      {'C': 1, 'kernel': 'rbf'}          -0.057075
# 2       linear  {'C': 10, 'kernel': 'linear'}           0.244411
# 3          rbf     {'C': 10, 'kernel': 'rbf'}          -0.033727
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.003709          -0.007947           0.007538          -0.000647
# 1          -0.050609          -0.062816          -0.050625          -0.061084
# 2           0.231086           0.228686           0.240853           0.248086
# 3          -0.027009          -0.038856          -0.024468          -0.031733
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.000636        0.005146                2
# 1        -0.056442        0.005108                4
# 2         0.238624        0.007531                1
# 3        -0.031159        0.005063                3

# %%
df_results.query('rank_test_score == 1')['params']
# Out:
# 2    {'C': 10, 'kernel': 'linear'}
# Name: params, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=42)

parameters = {
    'kernel' : ['linear', 'rbf'],
    'C' : [1, 10]
}

svr = SVR()

clf = GridSearchCV(svr, parameters, cv=10)

clf.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(),
#              param_grid={'C': [1, 10], 'kernel': ['linear', 'rbf']})

# %%
df_results = pd.DataFrame(clf.cv_results_)
df_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       8.195914      0.781028         0.484060        0.155933        1
# 1      10.751632      1.252072         1.083072        0.055904        1
# 2       7.449916      0.210708         0.418236        0.021568       10
# 3      10.147391      0.050695         1.089328        0.073653       10
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.004770
# 1          rbf      {'C': 1, 'kernel': 'rbf'}          -0.058905
# 2       linear  {'C': 10, 'kernel': 'linear'}           0.255954
# 3          rbf     {'C': 10, 'kernel': 'rbf'}          -0.033805
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.010875           0.004606           0.017027           0.002252
# 1          -0.054767          -0.050602          -0.052024          -0.055995
# 2           0.265722           0.226108           0.276440           0.236323
# 3          -0.027594          -0.029139          -0.019111          -0.031995
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0          -0.001796           0.013726           0.011313           0.006692
# 1          -0.069447          -0.047026          -0.055026          -0.059579
# 2           0.258242           0.248218           0.262238           0.260444
# 3          -0.036060          -0.019365          -0.026617          -0.028549
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.007618         0.007708        0.005343                2
# 1          -0.061658        -0.056503        0.005996                4
# 2           0.264244         0.255393        0.014077                1
# 3          -0.026126        -0.027836        0.005245                3

# %%
df_results.query('rank_test_score == 1')['params']
# Out:
# 2    {'C': 10, 'kernel': 'linear'}
# Name: params, dtype: object

# %%
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}
